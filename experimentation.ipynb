# %% [markdown]
# # Adaptative Hibrid Graph Convolutional Network (AH-GCN).
#
# Este notebook tiene como objetivo explorar y experimentar con una arquitectura propuesta (una modificación de la GCN) para ver si puede aprender bien tanto en grafos homofílicos (donde la GCN suele funcionar bien) como en heterofílicos (donde no suele funcionar bien). La descripción de la arquitectura esta más detallada en la memoria, pero esta es la idea:
#
# $$X^{(l+1)} = \sigma \left( \alpha^{(l)} S_{LP} X^{(l)} W^{(l)} + (1 - \alpha^{(l)}) S_{HP} X^{(l)} W^{(l)} \right)$$
#
# Como se puede apreciar, es muy similar a la GCN. La modificación propuesta es, en cada capa, combinar dos GSO distintos, uno *low pass* y otro *high pass*, con un regulador $\alpha$, que idealmente se aprendera por la red para que esta le pueda dar mas importancia a las frecuencias bajas (homofilia) o a las altas (heterofilia). Además, la idea también es que la red, en caso de que sea necesario, pueda saturar el $\alpha$ a uno y así recupere perfectamente una GCN estandar.

# %%
# Librerias 
import torch
import torch_geometric

print(f"Version actual de torch: {torch.__version__}\n"
      f"Version actual de torch geometric: {torch_geometric.__version__}")

print(f"[IMPORTANTE] Las versiones de torch y torch_geometric utilizadas para este notebook son 2.9.1+cu130 y 2.7.0 respectivamente.")
print(f"[RECORDATORIO] Todas las versiones utilizadas para este notebook se encuentran en el req.txt para instalar")
# Out:
# Version actual de torch: 2.9.1+cu130
# Version actual de torch geometric: 2.7.0
# [IMPORTANTE] Las versiones de torch y torch_geometric utilizadas para este notebook son 2.9.1+cu130 y 2.7.0 respectivamente.
# [RECORDATORIO] Todas las versiones utilizadas para este notebook se encuentran en el req.txt para instalar

# %%
# Por si fuese necesario
#pip install req.txt

# %% [markdown]
# ## 1. Preparacion de los datos
#
# En esta sección realizaremos las descargas y preparaciones pertinentes de los distintos datasets (benchmarks) para la evaluacion.

# %% [markdown]
# ## 2. Modelos propuestos
#
# En esta sección se expondrán los distintos modelos propuestos para las pruebas.

# %% [markdown]
# ## 3. Entrenamiento
#
# En esta sección se entrenaran los diferentes modelos propuestos.

# %% [markdown]
# ## 4. Resultados
#
# En esta última sección se mostrar los resultados obtendios, aunque alternativamente se podrán ver mejor mediante el dashboard de **Weights & Biases** y en la memoria.
